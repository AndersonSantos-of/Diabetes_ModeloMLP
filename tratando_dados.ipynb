# %%
import pandas as pd

# %%
df = pd.read_csv('pima-data.csv')
df.head()

# %%
traducao_colunas = {
    'num_preg':'gravidezes',
    'glucose_conc':'glicose',
    'diastolic_bp':'pressao_sangue',
    'thickness':'espessura',
    'insulin':'insulina',
    'bmi':'imc',
    'diab_pred':'diabete_p',
    'age':'idade',
    'diabetes':'resultado'
}

df.rename(columns = traducao_colunas, inplace=True)

# %%
df = df.drop(columns='skin')

# %%
#df.to_csv('diabete_em_indigenas.csv', index=False)
